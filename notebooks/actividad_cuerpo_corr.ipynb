# %%
# Montar Google Drive para acceder a los archivos del curso
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Los Shared Drives se montan en una ruta diferente
RAICES = [
    '/content/drive/MyDrive',
    '/content/drive/Shareddrives',   # Shared Drives (inglés)
    '/content/drive/Unidades\ compartidas',  # puede variar según idioma
]

for raiz in RAICES:
    if os.path.exists(raiz):
        print(f"\n--- Explorando: {raiz} ---")
        for root, dirs, files in os.walk(raiz):
            for file in files:
                if 'biovid' in file.lower():
                    print(os.path.join(root, file))
# Out:
# --- Explorando: /content/drive/MyDrive ---
# <>:7: SyntaxWarning: invalid escape sequence '\ '
# <>:7: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipykernel_22059/1748824686.py:7: SyntaxWarning: invalid escape sequence '\ '
#   '/content/drive/Unidades\ compartidas',  # puede variar según idioma
# --- Explorando: /content/drive/Shareddrives ---
# /content/drive/Shareddrives/DATA_GPI/Datasets Base (Sin modificar)/Biovid HeatPain Dataset-20260510T031356Z-3-001.zip
# /content/drive/Shareddrives/DATA_GPI/Nuestros Datasets/dataset_features_biovid.csv
# /content/drive/Shareddrives/DATA_GPI/Nuestros Datasets/dataset_features_biovid.xlsx
# /content/drive/Shareddrives/DATA_GPI/Nuestros Datasets/dataset_features_biovid_age.csv
# /content/drive/Shareddrives/DATA_GPI/Grupo2_Desarrollo/dataset_features_biovid.csv
# /content/drive/Shareddrives/DATA_GPI/Grupo1_Desarrollo/Entregable Grupo Uno/Actividad 2/dataset_features_biovid_age.csv
# /content/drive/Shareddrives/DATA_GPI/Grupo1_Desarrollo/Entregable Grupo Uno/Actividad 1/dataset_features_biovid.csv
# /content/drive/Shareddrives/DATA_GPI/Grupo1_Desarrollo/Entregable Grupo Uno/Actividad 1/dataset_features_biovid.gsheet

# %%
import pandas as pd

# Reemplaza esta ruta con la que imprimió el paso anterior
RUTA_ARCHIVO = '/content/drive/Shareddrives/DATA_GPI/Grupo2_Desarrollo/dataset_features_biovid.csv'

# Cargar el dataset
df_biovid = pd.read_csv(RUTA_ARCHIVO)

# Verificación inmediata: confirmar que cargó correctamente
print(f"Filas: {df_biovid.shape[0]} | Columnas: {df_biovid.shape[1]}")
print("\nColumnas disponibles:")
print(df_biovid.columns.tolist())
print("\nPrimeras 3 filas:")
df_biovid.head(3)
# Out:
# Filas: 8600 | Columnas: 23
#
# Columnas disponibles:
# ['subject_id', 'subject_name', 'class_id', 'class_name', 'sample_id', 'sample_name', 'max_temp', 'mean_temp', 'ecg_bpm', 'gsr_peaks_count', 'gsr_max_amplitude', 'emg_trapezius_max', 'emg_trapezius_mean', 'emg_trapezius_std', 'emg_trapezius_auc', 'emg_corrugator_max', 'emg_corrugator_mean', 'emg_corrugator_std', 'emg_corrugator_auc', 'emg_zygomaticus_max', 'emg_zygomaticus_mean', 'emg_zygomaticus_std', 'emg_zygomaticus_auc']
#
# Primeras 3 filas:
#    subject_id subject_name  class_id class_name  sample_id  \
# 0           1  071309_w_21         0        BL1          1
# 1           1  071309_w_21         0        BL1          2
# 2           1  071309_w_21         0        BL1          3
#
#            sample_name  max_temp  mean_temp    ecg_bpm  gsr_peaks_count  ...  \
# 0  071309_w_21-BL1-081    32.001  31.977767  76.363636              596  ...
# 1  071309_w_21-BL1-082    31.999  31.971261  76.363636              523  ...
# 2  071309_w_21-BL1-083    32.000  31.974500  76.363636              171  ...
#
#    emg_trapezius_std  emg_trapezius_auc  emg_corrugator_max  \
# 0           5.990114           5.090290            46.91209
# 1           1.243994           2.905451            31.08385
# 2           0.537993           0.864746            29.18040
#
#    emg_corrugator_mean  emg_corrugator_std  emg_corrugator_auc  \
# 0            10.070246            9.394042           55.382040
# 1             9.549088            8.459592           52.496094
# 2             5.652554            6.364855           31.074559
#
#    emg_zygomaticus_max  emg_zygomaticus_mean  emg_zygomaticus_std  \
# 0            123.03040             18.064247            17.404200
# 1             77.65277              8.981508             8.565125
# 2             27.92376              4.168286             4.325886
#
#    emg_zygomaticus_auc
# 0            99.331705
# 1            49.386495
# 2            22.922079
#
# [3 rows x 23 columns]

# %%
# Verificar que todas las columnas necesarias para el análisis existen
columnas_requeridas = [
    'class_id', 'ecg_bpm', 'gsr_peaks_count', 'gsr_max_amplitude',
    'emg_trapezius_mean', 'emg_corrugator_mean', 'emg_zygomaticus_mean'
]

columnas_faltantes = [col for col in columnas_requeridas if col not in df_biovid.columns]

if columnas_faltantes:
    print(f"ERROR: Faltan columnas: {columnas_faltantes}")
else:
    print("OK: Todas las columnas requeridas están presentes.")
    print(f"Dataset listo: {df_biovid.shape[0]} registros cargados.")
# Out:
# OK: Todas las columnas requeridas están presentes.
# Dataset listo: 8600 registros cargados.

# %%
# -*- coding: utf-8 -*-
"""actividad_cuerpo_corr - Matriz de Correlación de Pearson
Señales fisiológicas: corazón, músculos y nivel de dolor (BioVid)
"""

# Montar Google Drive para acceder a los archivos del curso
from google.colab import drive
drive.mount('/content/drive')

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# ─── 1. BUSCAR ARCHIVO ────────────────────────────────────────────────────────
RAICES = [
    '/content/drive/MyDrive',
    '/content/drive/Shareddrives',
    '/content/drive/Unidades compartidas', # La ruta puede variar según el idioma o configuración de Drive
]

for raiz in RAICES:
    if os.path.exists(raiz):
        print(f"\n--- Explorando: {raiz} ---")
        for root, dirs, files in os.walk(raiz):
            for file in files:
                if 'biovid' in file.lower():
                    print(os.path.join(root, file))

# ─── 2. CARGAR DATASET ───────────────────────────────────────────────────────
RUTA_ARCHIVO = '/content/drive/Shareddrives/DATA_GPI/Grupo2_Desarrollo/dataset_features_biovid.csv'

df_biovid = pd.read_csv(RUTA_ARCHIVO)

print(f"Filas: {df_biovid.shape[0]} | Columnas: {df_biovid.shape[1]}")
print("\nColumnas disponibles:")
print(df_biovid.columns.tolist())

# ─── 3. DEFINIR COLUMNAS POR CATEGORÍA ───────────────────────────────────────
# Columnas relacionadas con el nivel de dolor (variable objetivo)
cols_dolor = ['class_id']

# Columnas relacionadas con la señal cardíaca (ECG)
cols_corazon = ['ecg_bpm']

# Columnas relacionadas con las señales musculares (EMG)
cols_musculos = [
    'emg_trapezius_mean',
    'emg_corrugator_mean',
    'emg_zygomaticus_mean'
]

# Combinar todas las columnas de interés para el análisis
COLUMNAS_INTERES = cols_dolor + cols_corazon + cols_musculos

# ─── 4. VERIFICAR DISPONIBILIDAD ─────────────────────────────────────────────
columnas_faltantes = [col for col in COLUMNAS_INTERES if col not in df_biovid.columns]

if columnas_faltantes:
    raise ValueError(f"ERROR: Faltan las siguientes columnas en el dataset: {columnas_faltantes}")
else:
    print(f"\nOK: Todas las columnas requeridas están presentes.")

# ─── 5. FILTRAR Y LIMPIAR ────────────────────────────────────────────────────
# Seleccionar solo las columnas de interés y eliminar filas con valores nulos (NaN)
df_analisis = df_biovid[COLUMNAS_INTERES].dropna()

print(f"\nRegistros tras filtrar columnas y eliminar NaN: {df_analisis.shape[0]}")
print("Estadísticas descriptivas:")
print(df_analisis.describe().round(3))

# ─── 6. MATRIZ DE CORRELACIÓN DE PEARSON ─────────────────────────────────────
# Calcular la matriz de correlación de Pearson
corr_matrix = df_analisis.corr(method='pearson')

print("\nMatriz de correlación de Pearson:")
print(corr_matrix.round(3))

# ─── 7. VISUALIZACIÓN ────────────────────────────────────────────────────────

# Etiquetas legibles para los ejes del heatmap
etiquetas = {
    'class_id':              'Nivel de Dolor',
    'ecg_bpm':               'FC (ECG bpm)',
    'emg_trapezius_mean':    'EMG Trapecio',
    'emg_corrugator_mean':   'EMG Corrugador',
    'emg_zygomaticus_mean':  'EMG Zigomático'
}

corr_plot = corr_matrix.rename(index=etiquetas, columns=etiquetas)

# Máscara para ocultar el triángulo superior del heatmap (evita duplicados y mejora la lectura)
mask = np.triu(np.ones_like(corr_plot, dtype=bool), k=1)

fig, ax = plt.subplots(figsize=(8, 6))

sns.heatmap(
    corr_plot,
    mask=mask,
    annot=True,
    fmt='.3f',
    cmap='RdBu_r',        # 'RdBu_r': rojo para correlación positiva, azul para negativa
    vmin=-1, vmax=1,
    linewidths=0.5,
    linecolor='white',
    square=True,
    ax=ax,
    cbar_kws={'shrink': 0.8, 'label': 'r de Pearson'}
)

ax.set_title(
    'Correlación de Pearson\nCorazón · Músculos · Dolor (BioVid)',
    fontsize=13, fontweight='bold', pad=14
)
ax.tick_params(axis='x', rotation=30)
ax.tick_params(axis='y', rotation=0)

plt.tight_layout()
plt.savefig('correlacion_pearson_biovid.png', dpi=150, bbox_inches='tight')
plt.show()
print("\nGráfico guardado como: correlacion_pearson_biovid.png")

# ─── 8. INTERPRETACIÓN AUTOMÁTICA ────────────────────────────────────────────
print("\n── Correlaciones con Nivel de Dolor (|r| > 0.1) ──")
corr_dolor = corr_matrix['class_id'].drop('class_id').sort_values(key=abs, ascending=False)

for col, r in corr_dolor.items():
    if abs(r) > 0.1: # Se muestran solo las correlaciones con una magnitud considerable.
        direccion = "positiva" if r > 0 else "negativa"
        intensidad = (
            "fuerte" if abs(r) > 0.5 else
            "moderada" if abs(r) > 0.3 else
            "débil"
        )
        print(f"  {etiquetas.get(col, col):25s} r = {r:+.3f}  ({intensidad}, {direccion})")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# --- Explorando: /content/drive/MyDrive ---
#
# --- Explorando: /content/drive/Shareddrives ---
# /content/drive/Shareddrives/DATA_GPI/Datasets Base (Sin modificar)/Biovid HeatPain Dataset-20260510T031356Z-3-001.zip
# /content/drive/Shareddrives/DATA_GPI/Nuestros Datasets/dataset_features_biovid.csv
# /content/drive/Shareddrives/DATA_GPI/Nuestros Datasets/dataset_features_biovid.xlsx
# /content/drive/Shareddrives/DATA_GPI/Nuestros Datasets/dataset_features_biovid_age.csv
# /content/drive/Shareddrives/DATA_GPI/Grupo2_Desarrollo/dataset_features_biovid.csv
# /content/drive/Shareddrives/DATA_GPI/Grupo1_Desarrollo/Entregable Grupo Uno/Actividad 2/dataset_features_biovid_age.csv
# /content/drive/Shareddrives/DATA_GPI/Grupo1_Desarrollo/Entregable Grupo Uno/Actividad 1/dataset_features_biovid.csv
# /content/drive/Shareddrives/DATA_GPI/Grupo1_Desarrollo/Entregable Grupo Uno/Actividad 1/dataset_features_biovid.gsheet
# Filas: 8600 | Columnas: 23
#
# Columnas disponibles:
# ['subject_id', 'subject_name', 'class_id', 'class_name', 'sample_id', 'sample_name', 'max_temp', 'mean_temp', 'ecg_bpm', 'gsr_peaks_count', 'gsr_max_amplitude', 'emg_trapezius_max', 'emg_trapezius_mean', 'emg_trapezius_std', 'emg_trapezius_auc', 'emg_corrugator_max', 'emg_corrugator_mean', 'emg_corrugator_std', 'emg_corrugator_auc', 'emg_zygomaticus_max', 'emg_zygomaticus_mean', 'emg_zygomaticus_std', 'emg_zygomaticus_auc']
#
# OK: Todas las columnas requeridas están presentes.
#
# Registros tras filtrar columnas y eliminar NaN: 8600
# Estadísticas descriptivas:
#        class_id   ecg_bpm  emg_trapezius_mean  emg_corrugator_mean  \
# count  8600.000  8600.000        8.600000e+03             8600.000
# mean      2.000    64.792        3.067087e+06                4.414
# std       1.414    11.186        2.770092e+08               28.991
# min       0.000     0.000        0.000000e+00                0.000
# 25%       1.000    54.545        1.200000e-01                0.158
# 50%       2.000    65.455        3.790000e-01                0.575
# 75%       3.000    76.364        1.920000e+00                2.366
# max       4.000   109.091        2.568297e+10              966.308
#
#        emg_zygomaticus_mean
# count              8600.000
# mean                  2.854
# std                   8.364
# min                   0.000
# 25%                   0.104
# 50%                   0.482
# 75%                   2.117
# max                 200.062
#
# Matriz de correlación de Pearson:
#                       class_id  ecg_bpm  emg_trapezius_mean  \
# class_id                 1.000    0.079              -0.016
# ecg_bpm                  0.079    1.000              -0.064
# emg_trapezius_mean      -0.016   -0.064               1.000
# emg_corrugator_mean      0.023    0.012               0.003
# emg_zygomaticus_mean     0.175    0.102              -0.003
#
#                       emg_corrugator_mean  emg_zygomaticus_mean
# class_id                            0.023                 0.175
# ecg_bpm                             0.012                 0.102
# emg_trapezius_mean                  0.003                -0.003
# emg_corrugator_mean                 1.000                 0.089
# emg_zygomaticus_mean                0.089                 1.000
# Gráfico guardado como: correlacion_pearson_biovid.png
#
# ── Correlaciones con Nivel de Dolor (|r| > 0.1) ──
#   EMG Zigomático            r = +0.175  (débil, positiva)
